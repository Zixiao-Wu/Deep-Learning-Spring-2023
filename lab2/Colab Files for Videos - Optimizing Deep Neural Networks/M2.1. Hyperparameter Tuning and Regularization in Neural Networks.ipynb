# %% [markdown]
# # **DAT565E-Deep Learning for Prediction of Business Outcomes**

# %% [markdown]
# <div class="LI-profile-badge"  data-version="v1" data-size="large" data-locale="en_US" data-type="horizontal" data-theme="light" data-vanity="drsalihtutun"><a class="LI-simple-link" href='https://www.linkedin.com/in/drsalihtutun/en-us?trk=profile-badge'>Salih Tutun, PhD</a></div>

# %% [markdown]
# ![Imgur](https://i.imgur.com/4HJknC2.png)

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %% [markdown]
# ## Hyperparamaters Tuning

# %% [markdown]
# ![Imgur](https://i.imgur.com/8ktASPD.png)

# %% [markdown]
# ![Imgur](https://i.imgur.com/rbsCe3G.png)

# %% [markdown]
# ### Setting Up Deep Learning Applications

# %% [markdown]
# Randomly chosen parameters almost impossible!
# *   How many layers?
# *   How many layer units?
# *   Learning Rates
# *   Activation Functions
# *   Defining the best gradient descent approach

# %% [markdown]
# ### Dividing the dataset for Deep Learning

# %% [markdown]
# ![Imgur](https://i.imgur.com/mHERxtu.png)

# %% [markdown]
# ### Underfitting and Overfitting

# %% [markdown]
# ![Imgur](https://i.imgur.com/YCsBR29.png)

# %% [markdown]
# ![Imgur](https://i.imgur.com/zPjHnL5.png)

# %% [markdown]
# How can we understand there is underfitting or overfitting?

# %% [markdown]
# ![Imgur](https://i.imgur.com/pzIWFr7.png)

# %% [markdown]
# How to solve Underfitting and Overfitting?

# %% [markdown]
# ![Imgur](https://i.imgur.com/pQedNv0.png)

# %% [markdown]
# How regularization and dropout reduces overfitting?

# %% [markdown]
# ### Regularization for Overfitting Problem

# %% [markdown]
# - If you have a high variance and overfitting problem, we first use the regularization.
# - If we do not have a chance to get more dataset.
# - Lambda is regularization parameter
# - L2 and L1 regularization
# - How it works?

# %% [markdown]
# ![Imgur](https://i.imgur.com/DGGYSIa.png)

# %% [markdown]
# ### Dropout
#
# Weights spread all features, not one feature.

# %% [markdown]
# ![Imgur](https://i.imgur.com/ag5dSiD.png)

# %% [markdown]
# Other regularization methods

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# ![Imgur](https://i.imgur.com/g93936c.jpg?1)

# %% [markdown]
# ![Imgur](https://i.imgur.com/3giG4kS.png)

# %% [markdown]
# ### Early Stoping

# %% [markdown]
# ![Imgur](https://i.imgur.com/pfKKCy8.png)

# %% [markdown]
# ### Normalization

# %% [markdown]
# ![Imgur](https://i.imgur.com/hZiY7yW.png)

# %% [markdown]
# If you have questions, please contact with me.
#
# Salih Tutun, PhD
#
# salihtutun@wustl.edu
